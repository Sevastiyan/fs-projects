# %%
from tensorflow import keras
from models.ts_cnn import MULTI_CLASS_TS_CNN_23 as ts_cnn
import numpy as np
from sklearn.model_selection import train_test_split
from models.loader import loader
import matplotlib.pyplot as plt
from sklearn import preprocessing
from utils.normalisation import min_max

# %%
# %cd Desktop/pyscript/stf_main/

# %%
# Reading Data
slip_acc = np.loadtxt('data/multiclass_training_data/Slips/incidents_acc.txt')
slip_gyro = np.loadtxt('data/multiclass_training_data/Slips/incidents_gyro.txt')
trip_acc = np.loadtxt('data/multiclass_training_data/Trips/incidents_acc.txt')
trip_gyro = np.loadtxt('data/multiclass_training_data/Trips/incidents_gyro.txt')
no_incident_acc = np.loadtxt('data/multiclass_training_data/Base Case Walking/no_incidents_acc.txt')
no_incident_gyro = np.loadtxt('data/multiclass_training_data/Base Case Walking/no_incidents_gyro.txt')
x_noise_acc = np.random.rand(200, 200)
x_noise_gyro = np.random.rand(200, 200)

# %%
# Stacking
x_slip = np.stack([slip_acc, slip_gyro], axis=1)
x_trip = np.stack([trip_acc, trip_gyro], axis=1)
x_no_incident = np.stack([no_incident_acc, no_incident_gyro], axis=1)
x_noise = np.stack([x_noise_acc, x_noise_gyro], axis=1)
x_negative = np.concatenate([x_noise, x_no_incident])
x = np.concatenate([x_negative, x_slip, x_trip], axis=0)

# Labels
y_slip = np.ones(x_slip.shape[0]).astype(int)
y_trip = np.ones(x_trip.shape[0]) + 1
y_trip = y_trip.astype(int)
y_negative = np.zeros(x_negative.shape[0]).astype(int)
y_all = np.concatenate([y_negative, y_slip, y_trip])
y = keras.utils.to_categorical(y_all)

print(f'x slip: {x_slip.shape}')
print(f'x trip: {x_trip.shape}')
print(f'x no incident: {x_negative.shape}')
print('____________________________________')

#Check for nans
print(f'x: {x.shape}')
print(f'nans: {np.any(np.isnan(x))}')
print(f'y: {y.shape}')
# Out:
# x slip: (254, 2, 200)
# x trip: (244, 2, 200)
# x no incident: (280, 2, 200)
# ____________________________________
# x: (778, 2, 200)
# nans: False
# y: (778, 3)

# %%
# Shuffle data
idx = np.random.permutation(len(x))
x = x[idx]
y = y[idx]
y_all = y_all[idx]

# %%
model = ts_cnn()

# callbacks = [
#     keras.callbacks.ModelCheckpoint(
#         "best_model.h5", save_best_only=True, monitor="val_loss"
#     ),
#     keras.callbacks.ReduceLROnPlateau(
#         monitor="val_loss", factor=0.5, patience=20, min_lr=0.00001
#     ),
#     keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
#     ]

optimizer = keras.optimizers.Adam(learning_rate=0.00005)
model.compile(optimizer=optimizer,
                loss=["CategoricalCrossentropy"],
                metrics=["accuracy"])

# %%
epochs = 500
batch_size = 32
model.fit(
    [x[:,0], x[:,1]],
    y,
    batch_size=batch_size,
    epochs=epochs,
    # callbacks=callbacks,
    validation_split=0.4,
    verbose=2,
)
history = model.history.history
# Out:
# Epoch 1/500
# 15/15 - 5s - loss: 1.0551 - accuracy: 0.3326 - val_loss: 1.0471 - val_accuracy: 0.6122 - 5s/epoch - 341ms/step
# Epoch 2/500
# 15/15 - 0s - loss: 0.9838 - accuracy: 0.4142 - val_loss: 1.0199 - val_accuracy: 0.6218 - 319ms/epoch - 21ms/step
# Epoch 3/500
# 15/15 - 0s - loss: 0.9510 - accuracy: 0.4871 - val_loss: 0.9982 - val_accuracy: 0.6154 - 315ms/epoch - 21ms/step
# Epoch 4/500
# 15/15 - 0s - loss: 0
ms/step
# Epoch 479/500
# 15/15 - 0s - loss: 0.2104 - accuracy: 0.9270 - val_loss: 0.4786 - val_accuracy: 0.7885 - 380ms/epoch - 25ms/step
# Epoch 480/500
# 15/15 - 0s - loss: 0.2232 - accuracy: 0.9142 - val_loss: 0.3743 - val_accuracy: 0.8333 - 394ms/epoch - 26ms/step
# Epoch 481/500
# 15/15 - 0s - loss: 0.2014 - accuracy: 0.9292 - val_loss: 0.3955 - val_accuracy: 0.8109 - 387ms/epoch - 26ms/step
# Epoch 482/500
# 15/15 - 0s - loss: 0.2023 - accuracy: 0.9356 - val_loss: 0.3386 - val_accuracy: 0.8622 - 401ms/epoch - 27ms/step
# Epoch 483/500
# 15/15 - 0s - loss: 0.2274 - accuracy: 0.9142 - val_loss: 0.3993 - val_accuracy: 0.8109 - 406ms/epoch - 27ms/step
# Epoch 484/500
# 15/15 - 0s - loss: 0.2064 - accuracy: 0.9335 - val_loss: 0.3436 - val_accuracy: 0.8526 - 402ms/epoch - 27ms/step
# Epoch 485/500
# 15/15 - 0s - loss: 0.1909 - accuracy: 0.9399 - val_loss: 0.5022 - val_accuracy: 0.7821 - 405ms/epoch - 27ms/step
# Epoch 486/500
# 15/15 - 0s - loss: 0.2178 - accuracy: 0.9120 - val_loss: 0.3410 - val_accuracy: 0.8494 - 395ms/epoch - 26ms/step
# Epoch 487/500
# 15/15 - 0s - loss: 0.2198 - accuracy: 0.9227 - val_loss: 0.3094 - val_accuracy: 0.8622 - 391ms/epoch - 26ms/step
# Epoch 488/500
# 15/15 - 0s - loss: 0.1934 - accuracy: 0.9313 - val_loss: 0.3510 - val_accuracy: 0.8526 - 391ms/epoch - 26ms/step
# Epoch 489/500
# 15/15 - 0s - loss: 0.1969 - accuracy: 0.9227 - val_loss: 0.4144 - val_accuracy: 0.8045 - 404ms/epoch - 27ms/step
# Epoch 490/500
# 15/15 - 0s - loss: 0.1941 - accuracy: 0.9249 - val_loss: 0.3826 - val_accuracy: 0.8237 - 389ms/epoch - 26ms/step
# Epoch 491/500
# 15/15 - 0s - loss: 0.1917 - accuracy: 0.9313 - val_loss: 0.3368 - val_accuracy: 0.8590 - 400ms/epoch - 27ms/step
# Epoch 492/500
# 15/15 - 0s - loss: 0.2119 - accuracy: 0.9292 - val_loss: 0.4242 - val_accuracy: 0.8013 - 403ms/epoch - 27ms/step
# Epoch 493/500
# 15/15 - 0s - loss: 0.2008 - accuracy: 0.9442 - val_loss: 0.3384 - val_accuracy: 0.8686 - 396ms/epoch - 26ms/step
# Epoch 494/500
# 15/15 - 0s - loss: 0.1793 - accuracy: 0.9421 - val_loss: 0.3300 - val_accuracy: 0.8526 - 395ms/epoch - 26ms/step
# Epoch 495/500
# 15/15 - 0s - loss: 0.1913 - accuracy: 0.9485 - val_loss: 0.3877 - val_accuracy: 0.8173 - 411ms/epoch - 27ms/step
# Epoch 496/500
# 15/15 - 0s - loss: 0.2066 - accuracy: 0.9142 - val_loss: 0.2944 - val_accuracy: 0.8782 - 399ms/epoch - 27ms/step
# Epoch 497/500
# 15/15 - 0s - loss: 0.1889 - accuracy: 0.9399 - val_loss: 0.4154 - val_accuracy: 0.8045 - 405ms/epoch - 27ms/step
# Epoch 498/500
# 15/15 - 0s - loss: 0.2008 - accuracy: 0.9464 - val_loss: 0.3682 - val_accuracy: 0.8462 - 400ms/epoch - 27ms/step
# Epoch 499/500
# 15/15 - 0s - loss: 0.1915 - accuracy: 0.9378 - val_loss: 0.3954 - val_accuracy: 0.8333 - 396ms/epoch - 26ms/step
# Epoch 500/500
# 15/15 - 0s - loss: 0.1968 - accuracy: 0.9249 - val_loss: 0.3922 - val_accuracy: 0.8333 - 403ms/epoch - 27ms/step

# %%
plt.figure(figsize=(7, 10))
metric = "accuracy"
plt.subplot(2, 1, 1)
plt.plot(history[metric])
plt.plot(history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")

plt.subplot(2, 1, 2)
metric = "loss"
plt.plot(history[metric])
plt.plot(history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()

# %%
# Saving current model
import tensorflow as tf
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
with open('multi_class_categorical_model_v2_20230103.tflite', 'wb') as f:
    f.write(tflite_model)


# save model weights
model.save_weights("multi_class_categorical_model_weights_20220103.h5")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\joonn\AppData\Local\Temp\tmpxukbfy9v\assets
# INFO:tensorflow:Assets written to: C:\Users\joonn\AppData\Local\Temp\tmpxukbfy9v\assets

# %%
# Model Loader:

model = ts_cnn()
model.load_weights('multi_class_categorical_model_weights_20220103.h5')

# %%
idx = np.random.permutation(len(x))
x = x[idx]
y = y[idx]

print(f'First 5 samples: {y[:5]}') # see a couple of examples
np.argmax(y, axis=1)[:5]

# find how many positive and negative samples are in the dataset
print(f'positive: {np.sum(np.argmax(y, axis=1) == 0)}')
print(f'negative: {np.sum(np.argmax(y, axis=1) == 1)}')

# y_val = np.reshape(y, (len(y),))
y_val = y.argmax(axis=1)
y_pred = np.argmax(model.predict([x[:,0], x[:,1]]), axis=1)

# find how many positive and negative samples are in the predicted dataset
print(f'prediction_negative: {np.sum(y_pred == 0)}')
print(f'prediction_slip: {np.sum(y_pred == 1)}')
print(f'prediction_trip: {np.sum(y_pred == 2)}')
# Out:
# First 5 samples: [[1. 0. 0.]
#  [1. 0. 0.]
#  [0. 1. 0.]
#  [1. 0. 0.]
#  [0. 0. 1.]]
# positive: 280
# negative: 254
# 25/25 [==============================] - 1s 18ms/step
# prediction_negative: 284
# prediction_slip: 317
# prediction_trip: 177

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
#Create confusion matrix and normalizes it over predicted (columns)
result = confusion_matrix(y_val, y_pred, labels=[0,1,2])

# %%
result
# Out:
# array([[274,   6,   0],
#        [  0, 251,   3],
#        [ 10,  60, 174]], dtype=int64)

# %%
# Matrix without labels
ax = sns.heatmap(result/np.sum(result), annot=True,
            fmt='.2%', cmap='Blues')

ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Incidents')
ax.set_ylabel('Actual Incidents ');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['No Incident','Slip', 'Trip'])
ax.yaxis.set_ticklabels(['No Incident','Slip', 'Trip'])

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
# Matrix with labels
group_names = ['No Incident','False Slip','False Trip',
                'False No Incident', 'True Slip', 'False Slip',
                'False No Incident', 'False Slip', 'True Trip']
group_counts = ["{0:0.0f}".format(value) for value in result.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in result.flatten()/np.sum(result)]

labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(3,3)

ax = sns.heatmap(result, annot=labels, fmt='', cmap='Blues')
ax.set_title('Model Validation Confusion Matrix\n\n');
ax.set_xlabel('\nPredicted')
ax.set_ylabel('Actual');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['No Incident','Slip', 'Trip'])
ax.yaxis.set_ticklabels(['No Incident','Slip', 'Trip'])

## Display the visualization of the Confusion Matrix.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\joonn\Desktop\pyscript\stf_main\multiclass_training - 20230103.ipynb Cell 16 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/joonn/Desktop/pyscript/stf_main/multiclass_training%20-%2020230103.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> # Matrix with labels
#       <a href='vscode-notebook-cell:/c%3A/Users/joonn/Desktop/pyscript/stf_main/multiclass_training%20-%2020230103.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a> group_names = ['No Incident','False Slip','False Trip',
#       <a href='vscode-notebook-cell:/c%3A/Users/joonn/Desktop/pyscript/stf_main/multiclass_training%20-%2020230103.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a>                 'False No Incident', 'True Slip', 'False Slip',
#       <a href='vscode-notebook-cell:/c%3A/Users/joonn/Desktop/pyscript/stf_main/multiclass_training%20-%2020230103.ipynb#X20sZmlsZQ%3D%3D?line=3'>4</a>                 'False No Incident', 'False Slip', 'True Trip']
# ----> <a href='vscode-notebook-cell:/c%3A/Users/joonn/Desktop/pyscript/stf_main/multiclass_training%20-%2020230103.ipynb#X20sZmlsZQ%3D%3D?line=4'>5</a> group_counts = ["{0:0.0f}".format(value) for value in result.flatten()]
#       <a href='vscode-notebook-cell:/c%3A/Users/joonn/Desktop/pyscript/stf_main/multiclass_training%20-%2020230103.ipynb#X20sZmlsZQ%3D%3D?line=5'>6</a> group_percentages = ["{0:.2%}".format(value) for value in result.flatten()/np.sum(result)]
#       <a href='vscode-notebook-cell:/c%3A/Users/joonn/Desktop/pyscript/stf_main/multiclass_training%20-%2020230103.ipynb#X20sZmlsZQ%3D%3D?line=7'>8</a> labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
#
# NameError: name 'result' is not defined

# %%
# Matrix with labels
group_names = ['No Incident','False Pred Incident','False Pred No Inceint','Incident']
group_counts = ["{0:0.0f}".format(value) for value in result.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in result.flatten()/np.sum(result)]

labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)

ax = sns.heatmap(result, annot=labels, fmt='', cmap='Blues')
ax.set_title('Model Confusion Matrix\n\n');
ax.set_xlabel('\nPredicted')
ax.set_ylabel('Actual');

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])

## Display the visualization of the Confusion Matrix.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\joonn\Desktop\pyscript\stf_main\multiclass_training.ipynb Cell 16 in <cell line: 9>()
#       <a href='vscode-notebook-cell:/c%3A/Users/joonn/Desktop/pyscript/stf_main/multiclass_training.ipynb#X21sZmlsZQ%3D%3D?line=5'>6</a> labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
#       <a href='vscode-notebook-cell:/c%3A/Users/joonn/Desktop/pyscript/stf_main/multiclass_training.ipynb#X21sZmlsZQ%3D%3D?line=6'>7</a> labels = np.asarray(labels).reshape(2,2)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/joonn/Desktop/pyscript/stf_main/multiclass_training.ipynb#X21sZmlsZQ%3D%3D?line=8'>9</a> ax = sns.heatmap(result, annot=labels, fmt='', cmap='Blues')
#      <a href='vscode-notebook-cell:/c%3A/Users/joonn/Desktop/pyscript/stf_main/multiclass_training.ipynb#X21sZmlsZQ%3D%3D?line=9'>10</a> ax.set_title('Model Confusion Matrix\n\n');
#      <a href='vscode-notebook-cell:/c%3A/Users/joonn/Desktop/pyscript/stf_main/multiclass_training.ipynb#X21sZmlsZQ%3D%3D?line=10'>11</a> ax.set_xlabel('\nPredicted')
#
# File c:\Users\joonn\.conda\envs\TF29_PY39\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File c:\Users\joonn\.conda\envs\TF29_PY39\lib\site-packages\seaborn\matrix.py:540, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     362 """Plot rectangular data as a color-encoded matrix.
#     363
#     364 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     537     ...     ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True)
#     538 """
#     539 # Initialize the plotter object
# --> 540 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     541                       annot_kws, cbar, cbar_kws, xticklabels,
#     542                       yticklabels, mask)
#     544 # Add the pcolormesh kwargs here
#     545 kwargs["linewidths"] = linewidths
#
# File c:\Users\joonn\.conda\envs\TF29_PY39\lib\site-packages\seaborn\matrix.py:173, in _HeatMapper.__init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     171         if annot_data.shape != plot_data.shape:
#     172             err = "`data` and `annot` must have same shape."
# --> 173             raise ValueError(err)
#     174     annot = True
#     176 # Save other attributes to the object
#
# ValueError: `data` and `annot` must have same shape.
