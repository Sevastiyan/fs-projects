# %%
from tensorflow import keras
from models.ts_cnn import MULTI_CLASS_TS_RNN as ts_cnn
# from models.ts_cnn import ATTENTION_MODEL_TS_CNN as ts_cnn
import numpy as np
from sklearn.model_selection import train_test_split
from models.loader import loader
import matplotlib.pyplot as plt
from sklearn import preprocessing
import random
# from utils.normalisation import min_max

# %%
# %cd Desktop/pyscript/stf_main/

def augment_data(data, factors=[0.7, 0.9, 1.0, 1.2, 1.5]):
    """
    Augment data by resampling with different factors and maintain original size and sequence.
    """
    augmented = []

    for sample in data:
        for factor in factors:
            # Resample
            original_indices = np.arange(len(sample))
            temp_length = int(len(sample) * factor)
            temp_indices = np.linspace(0, len(sample) - 1, temp_length)
            resampled = np.interp(temp_indices, original_indices, sample)

            # Restore original size
            if factor != 1.0:
                final_indices = np.linspace(0, len(resampled) - 1, len(sample))
                resampled = np.interp(
                    final_indices, np.arange(len(resampled)), resampled
                )

            augmented.append(resampled)

    return np.array(augmented)

# %%
# Reading Data
slip_acc = np.loadtxt('data/multiclass_training_data/Slips/incidents_acc.txt')
slip_gyro = np.loadtxt('data/multiclass_training_data/Slips/incidents_gyro.txt')
trip_acc = np.loadtxt('data/multiclass_training_data/Trips/incidents_acc.txt')
trip_gyro = np.loadtxt('data/multiclass_training_data/Trips/incidents_gyro.txt')

slip_acc = augment_data(slip_acc, factors=[0.8, 1.0, 1.2])
slip_gyro = augment_data(slip_gyro, factors=[0.8, 1.0, 1.2])
trip_acc = augment_data(trip_acc, factors=[0.8, 1.0, 1.2])
trip_gyro = augment_data(trip_gyro, factors=[0.8, 1.0, 1.2])


no_incident_acc = np.loadtxt('data/multiclass_training_data/Base Case Walking/no_incidents_acc.txt')
no_incident_gyro = np.loadtxt('data/multiclass_training_data/Base Case Walking/no_incidents_gyro.txt')

# no_incident_acc = augment_data(no_incident_acc, factors=[0.7, 0.8, 1.0, 1.2, 1.5])
# no_incident_gyro = augment_data(no_incident_gyro, factors=[0.7, 0.8, 1.0, 1.2, 1.5])

chaotic_acc = np.loadtxt("data/multiclass_training_data/JW Data/cwalking_acc.txt")
chaotic_gyro = np.loadtxt("data/multiclass_training_data/JW Data/cwalking_gyro.txt")

# chaotic_acc = augment_data(chaotic_acc, factors=[0.8, 1.0, 1.2])
# chaotic_gyro = augment_data(chaotic_gyro, factors=[0.8, 1.0, 1.2])

x_noise_acc = np.random.rand(400, 200)
x_noise_gyro = np.random.rand(400, 200)

# %%
# Stacking
x_slip = np.stack([slip_acc, slip_gyro], axis=1)
x_trip = np.stack([trip_acc, trip_gyro], axis=1)
x_no_incident = np.stack([no_incident_acc, no_incident_gyro], axis=1)
x_chaotic_walking = np.stack([chaotic_acc, chaotic_gyro], axis=1)
x_noise = np.stack([x_noise_acc, x_noise_gyro], axis=1)

x_negative = np.concatenate([x_noise, x_no_incident, x_chaotic_walking])
x_incidents = np.concatenate([x_slip, x_trip])

x = np.concatenate([x_negative, x_slip, x_trip], axis=0)

# Labels
y_slip = np.ones(x_slip.shape[0]).astype(int)
y_trip = np.ones(x_trip.shape[0]) + 1
y_trip = y_trip.astype(int)
y_negative = np.zeros(x_negative.shape[0]).astype(int)
y_all = np.concatenate([y_negative, y_slip, y_trip])
y = keras.utils.to_categorical(y_all)

print(f'x slip: {x_slip.shape}')
print(f'x trip: {x_trip.shape}')
print(f'x no incident: {x_negative.shape}')
print('____________________________________')

#Check for nans
print(f'x: {x.shape}')
print(f'nans: {np.any(np.isnan(x))}')
print(f'y: {y.shape}')
# Out:
# x slip: (762, 2, 200)
# x trip: (732, 2, 200)
# x no incident: (1656, 2, 200)
# ____________________________________
# x: (3150, 2, 200)
# nans: False
# y: (3150, 3)

# %%
def min_max(data):
    """
    Normalize the data to the range [0, 1].
    """
    min_val = np.min(data)
    max_val = np.max(data)
    if max_val - min_val == 0:
        return np.zeros_like(data)  # Handle constant arrays
    return (data - min_val) / (max_val - min_val)


# Assuming x is your 3D array with shape (samples, channels, features)
x_normalized = np.zeros_like(x)

for sample in range(x.shape[0]):  # iterate over samples
    for channel in range(x.shape[1]):  # iterate over channels (acc and gyro)
        x_normalized[sample, channel, :] = min_max(x[sample, channel, :])

# %%
print("Original data shape:", x.shape)
print("Normalized data shape:", x_normalized.shape)
print("Original data range:", np.min(x), "-", np.max(x))
print("Normalized data range:", np.min(x_normalized), "-", np.max(x_normalized))

# Check if each sample is indeed normalized to [0, 1]
for i in range(min(5, x.shape[0])):  # Check first 5 samples
    print(f"Sample {i} range:", np.min(x_normalized[i]), "-", np.max(x_normalized[i]))
# Out:
# Original data shape: (3150, 2, 200)
# Normalized data shape: (3150, 2, 200)
# Original data range: -9.81 - 3304.5274086629215
# Normalized data range: 0.0 - 1.0
# Sample 0 range: 0.0 - 1.0
# Sample 1 range: 0.0 - 1.0
# Sample 2 range: 0.0 - 1.0
# Sample 3 range: 0.0 - 1.0
# Sample 4 range: 0.0 - 1.0

# %%
# Shuffle data
idx = np.random.permutation(len(x_normalized))
x = x_normalized[idx]
y = y[idx]
y_all = y_all[idx]

# %%
model = ts_cnn()

# Create learning rate schedule for smoother decay
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=5e-4,  # Lower initial rate
    decay_steps=1000,
    decay_rate=0.95,
    staircase=True,
)

# Configure optimizer with more conservative parameters
optimizer = keras.optimizers.Adam(
    learning_rate=lr_schedule,
    beta_1=0.95,  # Increased momentum retention
    beta_2=0.999,
    epsilon=1e-07,
    clipnorm=1.0,  # Add gradient clipping
)

# Update model compilation
model.compile(
    optimizer=optimizer, loss=["CategoricalCrossentropy"], metrics=["accuracy"]
)

# %%
epochs = 300
batch_size = 64
model.fit(
    [x[:,0], x[:,1]],
    y,
    batch_size=batch_size,
    epochs=epochs,
    # callbacks=callbacks,
    validation_split=0.4,
    verbose=2,
)
history = model.history.history
# Out:
# Epoch 1/300
# 30/30 - 10s - loss: 0.7285 - accuracy: 0.6312 - val_loss: 0.9875 - val_accuracy: 0.5437 - 10s/epoch - 326ms/step
# Epoch 2/300
# 30/30 - 0s - loss: 0.6081 - accuracy: 0.7063 - val_loss: 1.1500 - val_accuracy: 0.3794 - 256ms/epoch - 9ms/step
# Epoch 3/300
# 30/30 - 0s - loss: 0.5793 - accuracy: 0.7143 - val_loss: 1.3654 - val_accuracy: 0.3024 - 249ms/epoch - 8ms/step
# Epoch 4/300
# 30/30 - 0s - loss: 0.5548 - accuracy: 0.7349 - val_loss: 1.6115 - val_accuracy: 0.2389 - 225ms/epoch - 8ms/step
# Epoch 5/300
# 30/30 - 0s - loss: 0.5238 - accuracy: 0.7656 - val_loss: 1.8123 - val_accuracy: 0.2381 - 229ms/epoch - 8ms/step
# Epoch 6/300
# 30/30 - 0s - loss: 0.5010 - accuracy: 0.7825 - val_loss: 2.0863 - val_accuracy: 0.2389 - 226ms/epoch - 8ms/step
# Epoch 7/300
# 30/30 - 0s - loss: 0.4739 - accuracy: 0.7989 - val_loss: 2.1822 - val_accuracy: 0.2389 - 237ms/epoch - 8ms/step
# Epoch 8/300
# 30/30 - 0s - loss: 0.4679 - accuracy: 0.7995 - val_loss: 2.2797 - val_accuracy: 0.2389 - 220ms/epoch - 7ms/step
# Epoch 9/300
# 30/30 - 0s - loss: 0.4547 - accuracy: 0.7937 - val_loss: 2.3721 - val_accuracy: 0.2389 - 229ms/epoch - 8ms/step
# Epoch 10/300
# 30/30 - 0s - loss: 0.4164 - accuracy: 0.8280 - val_loss: 2.2138 - val_accuracy: 0.2492 - 232ms/epoch - 8ms/step
# Epoch 11/300
# 30/30 - 0s - loss: 0.3812 - accuracy: 0.8434 - val_loss: 1.7503 - val_accuracy: 0.4048 - 211ms/epoch - 7ms/step
# Epoch 12/300
# 30/30 - 0s - loss: 0.3747 - accuracy: 0.8481 - val_loss: 1.8040 - val_accuracy: 0.3921 - 189ms/epoch - 6ms/step
# Epoch 13/300
# 30/30 - 0s - loss: 0.3547 - accuracy: 0.8508 - val_loss: 1.3446 - val_accuracy: 0.4516 - 207ms/epoch - 7ms/step
# Epoch 14/300
# 30/30 - 0s - loss: 0.3354 - accuracy: 0.8587 - val_loss: 1.0668 - val_accuracy: 0.5190 - 241ms/epoch - 8ms/step
# Epoch 15/300
# 30/30 - 0s - loss: 0.3133 - accuracy: 0.8735 - val_loss: 1.0372 - val_accuracy: 0.5317 - 227ms/epoch - 8ms/step
# Epoch 16/300
# 30/30 - 0s - loss: 0.3051 - accuracy: 0.8661 - val_loss: 0.7736 - val_accuracy: 0.6413 - 220ms/epoch - 7ms/step
# Epoch 17/300
# 30/30 - 0s - loss: 0.3077 - accuracy: 0.8720 - val_loss: 0.7257 - val_accuracy: 0.6405 - 233ms/epoch - 8ms/step
# Epoch 18/300
# 30/30 - 0s - loss: 0.2926 - accuracy: 0.8852 - val_loss: 0.6426 - val_accuracy: 0.7325 - 206ms/epoch - 7ms/step
# Epoch 19/300
# 30/30 - 0s - loss: 0.2774 - accuracy: 0.8857 - val_loss: 0.6451 - val_accuracy: 0.7048 - 218ms/epoch - 7ms/step
# Epoch 20/300
# 30/30 - 0s - loss: 0.2755 - accuracy: 0.8836 - val_loss: 0.6203 - val_accuracy: 0.7421 - 189ms/epoch - 6ms/step
# Epoch 21/300
# 30/30 - 0s - loss: 0.2607 - accuracy: 0.8947 - val_loss: 0.5628 - val_accuracy: 0.7437 - 222ms/epoch - 7ms/step
# Epoch 22/300
# 30/30 - 0s - loss: 0.2537 - accuracy: 0.8942 - val_loss: 0.3825 - val_accuracy: 0.8476 - 238ms/epoch - 8ms/step
# Epoch 23/300
# 30/30 - 0s - loss: 0.2602 - accuracy: 0.8963 - val_loss: 0.5208 - val_accuracy: 0.7802 - 210ms/epoch - 7ms/step
# Epoch 24/300
# 30/30 - 0s - loss: 0.2461 - accuracy: 0.9016 - val_loss: 0.3697 - val_accuracy: 0.8444 - 214ms/epoch - 7ms/step
# Epoch 25/300
# 30/30 - 0s - loss: 0.2303 - accuracy: 0.9132 - val_loss: 0.2985 - val_accuracy: 0.8881 - 205ms/epoch - 7ms/step
# Epoch 26/300
# 30/30 - 0s - loss: 0.2297 - accuracy: 0.9085 - val_loss: 0.3904 - val_accuracy: 0.8333 - 201ms/epoch - 7ms/step
# Epoch 27/300
# 30/30 - 0s - loss: 0.2137 - accuracy: 0.9122 - val_loss: 0.3075 - val_accuracy: 0.8778 - 194ms/epoch - 6ms/step
# Epoch 28/300
# 30/30 - 0s - loss: 0.2063 - accuracy: 0.9159 - val_loss: 0.3281 - val_accuracy: 0.8476 - 204ms/epoch - 7ms/step
# Epoch 29/300
# 30/30 - 0s - loss: 0.2158 - accuracy: 0.9148 - val_loss: 0.3181 - val_accuracy: 0.8722 - 195ms/epoch - 7ms/step
# Epoch 30/300
# 30/30 - 0s - loss: 0.2097 - accuracy: 0.9175 - val_loss: 0.3733 - val_accuracy: 0.8548 - 216ms/epoch - 7ms/step
# Epoch 31/300
# 30/30 - 0s - loss: 0.1999 - accuracy: 0.9249 - val_loss: 0.2670 - val_accuracy: 0.8944 - 204ms/epoch - 7ms/step
# Epoch 32/300
# 30/30 - 0s - loss: 0.1992 - accuracy: 0.9196 - val_loss: 0.3366 - val_accuracy: 0.8595 - 203ms/epoch - 7ms/step
# Epoch 33/300
# 30/30 - 0s - loss: 0.1917 - accuracy: 0.9275 - val_loss: 0.3174 - val_accuracy: 0.8762 - 233ms/epoch - 8ms/step
# Epoch 34/300
# 30/30 - 0s - loss: 0.1846 - accuracy: 0.9296 - val_loss: 0.3316 - val_accuracy: 0.8508 - 226ms/epoch - 8ms/step
# Epoch 35/300
# 30/30 - 0s - loss: 0.1808 - accuracy: 0.9249 - val_loss: 0.3353 - val_accuracy: 0.8675 - 224ms/epoch - 7ms/step
# Epoch 36/300
# 30/30 - 0s - loss: 0.1769 - accuracy: 0.9296 - val_loss: 0.3249 - val_accuracy: 0.8683 - 211ms/epoch - 7ms/step
# Epoch 37/300
# 30/30 - 0s - loss: 0.1755 - accuracy: 0.9317 - val_loss: 0.2330 - val_accuracy: 0.9048 - 227ms/epoch - 8ms/step
# Epoch 38/300
# 30/30 - 0s - loss: 0.1676 - accuracy: 0.9349 - val_loss: 0.2283 - val_accuracy: 0.9167 - 217ms/epoch - 7ms/step
# Epoch 39/300
# 30/30 - 0s - loss: 0.1711 - accuracy: 0.9317 - val_loss: 0.2526 - val_accuracy: 0.9000 - 222ms/epoch - 7ms/step
# Epoch 40/300
# 30/30 - 0s - loss: 0.1839 - accuracy: 0.9249 - val_loss: 0.2020 - val_accuracy: 0.9214 - 224ms/epoch - 7ms/step
# Epoch 41/300
# 30/30 - 0s - loss: 0.1936 - accuracy: 0.9201 - val_loss: 0.2056 - val_accuracy: 0.9048 - 245ms/epoch - 8ms/step
# Epoch 42/300
# 30/30 - 0s - loss: 0.1715 - accuracy: 0.9339 - val_loss: 0.1964 - val_accuracy: 0.9127 - 216ms/epoch - 7ms/step
# Epoch 43/300
# 30/30 - 0s - loss: 0.1633 - accuracy: 0.9365 - val_loss: 0.2292 - val_accuracy: 0.9008 - 230ms/epoch - 8ms/step
# Epoch 44/300
# 30/30 - 0s - loss: 0.1599 - accuracy: 0.9381 - val_loss: 0.2156 - val_accuracy: 0.9079 - 213ms/epoch - 7ms/step
# Epoch 45/300
# 30/30 - 0s - loss: 0.1590 - accuracy: 0.9423 - val_loss: 0.2256 - val_accuracy: 0.9095 - 226ms/epoch - 8ms/step
# Epoch 46/300
# 30/30 - 0s - loss: 0.1669 - accuracy: 0.9370 - val_loss: 0.2266 - val_accuracy: 0.9040 - 260ms/epoch - 9ms/step
# Epoch 47/300
# 30/30 - 0s - loss: 0.1565 - accuracy: 0.9423 - val_loss: 0.1864 - val_accuracy: 0.9222 - 216ms/epoch - 7ms/step
# Epoch 48/300
# 30/30 - 0s - loss: 0.1697 - accuracy: 0.9291 - val_loss: 0.2932 - val_accuracy: 0.8778 - 222ms/epoch - 7ms/step
# Epoch 49/300
# 30/30 - 0s - loss: 0.1654 - accuracy: 0.9354 - val_loss: 0.2763 - val_accuracy: 0.8746 - 211ms/epoch - 7ms/step
# Epoch 50/300
# 30/30 - 0s - loss: 0.1518 - accuracy: 0.9407 - val_loss: 0.2899 - val_accuracy: 0.8698 - 217ms/epoch - 7ms/step
# Epoch 51/300
# 30/30 - 0s - loss: 0.1473 - accuracy: 0.9481 - val_loss: 0.2157 - val_accuracy: 0.9008 - 229ms/epoch - 8ms/step
# Epoch 52/300
# 30/30 - 0s - loss: 0.1434 - accuracy: 0.9397 - val_loss: 0.1971 - val_accuracy: 0.9167 - 205ms/epoch - 7ms/step
# Epoch 53/300
# 30/30 - 0s - loss: 0.1414 - accuracy: 0.9481 - val_loss: 0.2047 - val_accuracy: 0.9095 - 235ms/epoch - 8ms/step
# Epoch 54/300
# 30/30 - 0s - loss: 0.1255 - accuracy: 0.9545 - val_loss: 0.2449 - val_accuracy: 0.8905 - 213ms/epoch - 7ms/step
# Epoch 55/300
# 30/30 - 0s - loss: 0.1463 - accuracy: 0.9397 - val_loss: 0.1812 - val_accuracy: 0.9206 - 229ms/epoch - 8ms/step
# Epoch 56/300
# 30/30 - 0s - loss: 0.1261 - accuracy: 0.9550 - val_loss: 0.2357 - val_accuracy: 0.9071 - 205ms/epoch - 7ms/step
# Epoch 57/300
# 30/30 - 0s - loss: 0.1389 - accuracy: 0.9508 - val_loss: 0.1870 - val_accuracy: 0.9254 - 218ms/epoch - 7ms/step
# Epoch 58/300
# 30/30 - 0s - loss: 0.1322 - accuracy: 0.9492 - val_loss: 0.2308 - val_accuracy: 0.9087 - 212ms/epoch - 7ms/step
# Epoch 59/300
# 30/30 - 0s - loss: 0.1252 - accuracy: 0.9534 - val_loss: 0.2114 - val_accuracy: 0.9143 - 200ms/epoch - 7ms/step
# Epoch 60/300
# 30/30 - 0s - loss: 0.1312 - accuracy: 0.9471 - val_loss: 0.1963 - val_accuracy: 0.9230 - 212ms/epoch - 7ms/step
# Epoch 61/300
# 30/30 - 0s - loss: 0.1177 - accuracy: 0.9550 - val_loss: 0.1672 - val_accuracy: 0.9262 - 205ms/epoch - 7ms/step
# Epoch 62/300
# 30/30 - 0s - loss: 0.1248 - accuracy: 0.9481 - val_loss: 0.1784 - val_accuracy: 0.9262 - 245ms/epoch - 8ms/step
# Epoch 63/300
# 30/30 - 0s - loss: 0.1322 - accuracy: 0.9471 - val_loss: 0.1639 - val_accuracy: 0.9333 - 212ms/epoch - 7ms/step
# Epoch 64/300
# 30/30 - 0s - loss: 0.1153 - accuracy: 0.9566 - val_loss: 0.1965 - val_accuracy: 0.9190 - 204ms/epoch - 7ms/step
# Epoch 65/300
# 30/30 - 0s - loss: 0.1208 - accuracy: 0.9524 - val_loss: 0.1368 - val_accuracy: 0.9429 - 217ms/epoch - 7ms/step
# Epoch 66/300
# 30/30 - 0s - loss: 0.1130 - accuracy: 0.9540 - val_loss: 0.2142 - val_accuracy: 0.9151 - 235ms/epoch - 8ms/step
# Epoch 67/300
# 30/30 - 0s - loss: 0.1300 - accuracy: 0.9487 - val_loss: 0.1692 - val_accuracy: 0.9286 - 215ms/epoch - 7ms/step
# Epoch 68/300
# 30/30 - 0s - loss: 0.1307 - accuracy: 0.9407 - val_loss: 0.1508 - val_accuracy: 0.9429 - 228ms/epoch - 8ms/step
# Epoch 69/300
# 30/30 - 0s - loss: 0.1272 - accuracy: 0.9476 - val_loss: 0.1506 - val_accuracy: 0.9484 - 217ms/epoch - 7ms/step
# Epoch 70/300
# 30/30 - 0s - loss: 0.1057 - accuracy: 0.9614 - val_loss: 0.1543 - val_accuracy: 0.9302 - 234ms/epoch - 8ms/step
# Epoch 71/300
# 30/30 - 0s - loss: 0.1128 - accuracy: 0.9561 - val_loss: 0.1388 - val_accuracy: 0.9452 - 237ms/epoch - 8ms/step
# Epoch 72/300
# 30/30 - 0s - loss: 0.1211 - accuracy: 0.9550 - val_loss: 0.2057 - val_accuracy: 0.9048 - 228ms/epoch - 8ms/step
# Epoch 73/300
# 30/30 - 0s - loss: 0.1053 - accuracy: 0.9598 - val_loss: 0.1823 - val_accuracy: 0.9206 - 214ms/epoch - 7ms/step
# Epoch 74/300
# 30/30 - 0s - loss: 0.1007 - accuracy: 0.9593 - val_loss: 0.1779 - val_accuracy: 0.9246 - 216ms/epoch - 7ms/step
# Epoch 75/300
# 30/30 - 0s - loss: 0.1065 - accuracy: 0.9545 - val_loss: 0.1544 - val_accuracy: 0.9413 - 234ms/epoch - 8ms/step
# Epoch 76/300
# 30/30 - 0s - loss: 0.1061 - accuracy: 0.9587 - val_loss: 0.1733 - val_accuracy: 0.9286 - 216ms/epoch - 7ms/step
# Epoch 77/300
# 30/30 - 0s - loss: 0.1077 - accuracy: 0.9571 - val_loss: 0.1468 - val_accuracy: 0.9413 - 223ms/epoch - 7ms/step
# Epoch 78/300
# 30/30 - 0s - loss: 0.0983 - accuracy: 0.9630 - val_loss: 0.1456 - val_accuracy: 0.9452 - 211ms/epoch - 7ms/step
# Epoch 79/300
# 30/30 - 0s - loss: 0.0912 - accuracy: 0.9630 - val_loss: 0.1829 - val_accuracy: 0.9310 - 229ms/epoch - 8ms/step
# Epoch 80/300
# 30/30 - 0s - loss: 0.1020 - accuracy: 0.9603 - val_loss: 0.1525 - val_accuracy: 0.9381 - 235ms/epoch - 8ms/step
# Epoch 81/300
# 30/30 - 0s - loss: 0.0975 - accuracy: 0.9608 - val_loss: 0.2704 - val_accuracy: 0.8960 - 224ms/epoch - 7ms/step
# Epoch 82/300
# 30/30 - 0s - loss: 0.1065 - accuracy: 0.9614 - val_loss: 0.1444 - val_accuracy: 0.9468 - 203ms/epoch - 7ms/step
# Epoch 83/300
# 30/30 - 0s - loss: 0.1034 - accuracy: 0.9635 - val_loss: 0.1628 - val_accuracy: 0.9341 - 246ms/epoch - 8ms/step
# Epoch 84/300
# 30/30 - 0s - loss: 0.1068 - accuracy: 0.9571 - val_loss: 0.1705 - val_accuracy: 0.9317 - 238ms/epoch - 8ms/step
# Epoch 85/300
# 30/30 - 0s - loss: 0.1275 - accuracy: 0.9534 - val_loss: 0.1830 - val_accuracy: 0.9230 - 238ms/epoch - 8ms/step
# Epoch 86/300
# 30/30 - 0s - loss: 0.1056 - accuracy: 0.9614 - val_loss: 0.1371 - val_accuracy: 0.9452 - 222ms/epoch - 7ms/step
# Epoch 87/300
# 30/30 - 0s - loss: 0.0881 - accuracy: 0.9672 - val_loss: 0.1526 - val_accuracy: 0.9413 - 225ms/epoch - 8ms/step
# Epoch 88/300
# 30/30 - 0s - loss: 0.0888 - accuracy: 0.9688 - val_loss: 0.1554 - val_accuracy: 0.9381 - 262ms/epoch - 9ms/step
# Epoch 89/300
# 30/30 - 0s - loss: 0.0953 - accuracy: 0.9614 - val_loss: 0.1752 - val_accuracy: 0.9333 - 232ms/epoch - 8ms/step
# Epoch 90/300
# 30/30 - 0s - loss: 0.1012 - accuracy: 0.9635 - val_loss: 0.1993 - val_accuracy: 0.9175 - 225ms/epoch - 7ms/step
# Epoch 91/300
# 30/30 - 0s - loss: 0.1177 - accuracy: 0.9471 - val_loss: 0.1459 - val_accuracy: 0.9405 - 217ms/epoch - 7ms/step
# Epoch 92/300
# 30/30 - 0s - loss: 0.0962 - accuracy: 0.9635 - val_loss: 0.2596 - val_accuracy: 0.9000 - 212ms/epoch - 7ms/step
# Epoch 93/300
# 30/30 - 0s - loss: 0.0963 - accuracy: 0.9598 - val_loss: 0.1848 - val_accuracy: 0.9238 - 218ms/epoch - 7ms/step
# Epoch 94/300
# 30/30 - 0s - loss: 0.0837 - accuracy: 0.9630 - val_loss: 0.2419 - val_accuracy: 0.9040 - 204ms/epoch - 7ms/step
# Epoch 95/300
# 30/30 - 0s - loss: 0.0874 - accuracy: 0.9661 - val_loss: 0.1556 - val_accuracy: 0.9365 - 218ms/epoch - 7ms/step
# Epoch 96/300
# 30/30 - 0s - loss: 0.0805 - accuracy: 0.9714 - val_loss: 0.1509 - val_accuracy: 0.9429 - 213ms/epoch - 7ms/step
# Epoch 97/300
# 30/30 - 0s - loss: 0.0747 - accuracy: 0.9709 - val_loss: 0.1327 - val_accuracy: 0.9492 - 212ms/epoch - 7ms/step
# Epoch 98/300
# 30/30 - 0s - loss: 0.0740 - accuracy: 0.9735 - val_loss: 0.1082 - val_accuracy: 0.9595 - 228ms/epoch - 8ms/step
# Epoch 99/300
# 30/30 - 0s - loss: 0.0856 - accuracy: 0.9656 - val_loss: 0.1241 - val_accuracy: 0.9476 - 213ms/epoch - 7ms/step
# Epoch 100/300
# 30/30 - 0s - loss: 0.0909 - accuracy: 0.9667 - val_loss: 0.1136 - val_accuracy: 0.9571 - 225ms/epoch - 8ms/step
# Epoch 101/300
# 30/30 - 0s - loss: 0.0904 - accuracy: 0.9624 - val_loss: 0.1721 - val_accuracy: 0.9310 - 225ms/epoch - 7ms/step
# Epoch 102/300
# 30/30 - 0s - loss: 0.0820 - accuracy: 0.9693 - val_loss: 0.1588 - val_accuracy: 0.9365 - 229ms/epoch - 8ms/step
# Epoch 103/300
# 30/30 - 0s - loss: 0.0730 - accuracy: 0.9741 - val_loss: 0.1087 - val_accuracy: 0.9587 - 230ms/epoch - 8ms/step
# Epoch 104/300
# 30/30 - 0s - loss: 0.0919 - accuracy: 0.9683 - val_loss: 0.1239 - val_accuracy: 0.9476 - 216ms/epoch - 7ms/step
# Epoch 105/300
# 30/30 - 0s - loss: 0.0929 - accuracy: 0.9698 - val_loss: 0.1080 - val_accuracy: 0.9571 - 205ms/epoch - 7ms/step
# Epoch 106/300
# 30/30 - 0s - loss: 0.0734 - accuracy: 0.9720 - val_loss: 0.1207 - val_accuracy: 0.9579 - 233ms/epoch - 8ms/step
# Epoch 107/300
# 30/30 - 0s - loss: 0.0729 - accuracy: 0.9709 - val_loss: 0.1298 - val_accuracy: 0.9500 - 229ms/epoch - 8ms/step
# Epoch 108/300
# 30/30 - 0s - loss: 0.0684 - accuracy: 0.9757 - val_loss: 0.1165 - val_accuracy: 0.9563 - 225ms/epoch - 8ms/step
# Epoch 109/300
# 30/30 - 0s - loss: 0.0823 - accuracy: 0.9725 - val_loss: 0.1472 - val_accuracy: 0.9421 - 224ms/epoch - 7ms/step
# Epoch 110/300
# 30/30 - 0s - loss: 0.0841 - accuracy: 0.9677 - val_loss: 0.1016 - val_accuracy: 0.9579 - 209ms/epoch - 7ms/step
# Epoch 111/300
# 30/30 - 0s - loss: 0.0812 - accuracy: 0.9704 - val_loss: 0.1090 - val_accuracy: 0.9579 - 221ms/epoch - 7ms/step
# Epoch 112/300
# 30/30 - 0s - loss: 0.0913 - accuracy: 0.9667 - val_loss: 0.1251 - val_accuracy: 0.9556 - 221ms/epoch - 7ms/step
# Epoch 113/300
# 30/30 - 0s - loss: 0.0865 - accuracy: 0.9651 - val_loss: 0.1439 - val_accuracy: 0.9421 - 212ms/epoch - 7ms/step
# Epoch 114/300
# 30/30 - 0s - loss: 0.0774 - accuracy: 0.9698 - val_loss: 0.1181 - val_accuracy: 0.9516 - 209ms/epoch - 7ms/step
# Epoch 115/300
# 30/30 - 0s - loss: 0.0717 - accuracy: 0.9720 - val_loss: 0.1188 - val_accuracy: 0.9532 - 213ms/epoch - 7ms/step
# Epoch 116/300
# 30/30 - 0s - loss: 0.0695 - accuracy: 0.9741 - val_loss: 0.1388 - val_accuracy: 0.9460 - 211ms/epoch - 7ms/step
# Epoch 117/300
# 30/30 - 0s - loss: 0.0680 - accuracy: 0.9714 - val_loss: 0.1005 - val_accuracy: 0.9587 - 217ms/epoch - 7ms/step
# Epoch 118/300
# 30/30 - 0s - loss: 0.0639 - accuracy: 0.9751 - val_loss: 0.1153 - val_accuracy: 0.9540 - 212ms/epoch - 7ms/step
# Epoch 119/300
# 30/30 - 0s - loss: 0.0804 - accuracy: 0.9688 - val_loss: 0.1712 - val_accuracy: 0.9357 - 212ms/epoch - 7ms/step
# Epoch 120/300
# 30/30 - 0s - loss: 0.0764 - accuracy: 0.9704 - val_loss: 0.1251 - val_accuracy: 0.9524 - 221ms/epoch - 7ms/step
# Epoch 121/300
# 30/30 - 0s - loss: 0.0598 - accuracy: 0.9778 - val_loss: 0.1585 - val_accuracy: 0.9413 - 226ms/epoch - 8ms/step
# Epoch 122/300
# 30/30 - 0s - loss: 0.0732 - accuracy: 0.9704 - val_loss: 0.1664 - val_accuracy: 0.9341 - 220ms/epoch - 7ms/step
# Epoch 123/300
# 30/30 - 0s - loss: 0.0986 - accuracy: 0.9598 - val_loss: 0.1292 - val_accuracy: 0.9516 - 230ms/epoch - 8ms/step
# Epoch 124/300
# 30/30 - 0s - loss: 0.0844 - accuracy: 0.9698 - val_loss: 0.1607 - val_accuracy: 0.9349 - 208ms/epoch - 7ms/step
# Epoch 125/300
# 30/30 - 0s - loss: 0.0636 - accuracy: 0.9767 - val_loss: 0.1973 - val_accuracy: 0.9230 - 230ms/epoch - 8ms/step
# Epoch 126/300
# 30/30 - 0s - loss: 0.0667 - accuracy: 0.9751 - val_loss: 0.1458 - val_accuracy: 0.9421 - 233ms/epoch - 8ms/step
# Epoch 127/300
# 30/30 - 0s - loss: 0.0566 - accuracy: 0.9820 - val_loss: 0.1376 - val_accuracy: 0.9492 - 210ms/epoch - 7ms/step
# Epoch 128/300
# 30/30 - 0s - loss: 0.0693 - accuracy: 0.9714 - val_loss: 0.1415 - val_accuracy: 0.9381 - 219ms/epoch - 7ms/step
# Epoch 129/300
# 30/30 - 0s - loss: 0.0560 - accuracy: 0.9815 - val_loss: 0.1771 - val_accuracy: 0.9357 - 222ms/epoch - 7ms/step
# Epoch 130/300
# 30/30 - 0s - loss: 0.0610 - accuracy: 0.9783 - val_loss: 0.1505 - val_accuracy: 0.9397 - 212ms/epoch - 7ms/step
# Epoch 131/300
# 30/30 - 0s - loss: 0.0622 - accuracy: 0.9772 - val_loss: 0.1252 - val_accuracy: 0.9508 - 209ms/epoch - 7ms/step
# Epoch 132/300
# 30/30 - 0s - loss: 0.0585 - accuracy: 0.9815 - val_loss: 0.1465 - val_accuracy: 0.9429 - 217ms/epoch - 7ms/step
# Epoch 133/300
# 30/30 - 0s - loss: 0.0623 - accuracy: 0.9788 - val_loss: 0.1213 - val_accuracy: 0.9532 - 227ms/epoch - 8ms/step
# Epoch 134/300
# 30/30 - 0s - loss: 0.0651 - accuracy: 0.9794 - val_loss: 0.1105 - val_accuracy: 0.9556 - 218ms/epoch - 7ms/step
# Epoch 135/300
# 30/30 - 0s - loss: 0.0608 - accuracy: 0.9762 - val_loss: 0.1631 - val_accuracy: 0.9373 - 243ms/epoch - 8ms/step
# Epoch 136/300
# 30/30 - 0s - loss: 0.0500 - accuracy: 0.9831 - val_loss: 0.1431 - val_accuracy: 0.9444 - 225ms/epoch - 8ms/step
# Epoch 137/300
# 30/30 - 0s - loss: 0.0488 - accuracy: 0.9815 - val_loss: 0.1064 - val_accuracy: 0.9540 - 225ms/epoch - 8ms/step
# Epoch 138/300
# 30/30 - 0s - loss: 0.0601 - accuracy: 0.9778 - val_loss: 0.1022 - val_accuracy: 0.9595 - 237ms/epoch - 8ms/step
# Epoch 139/300
# 30/30 - 0s - loss: 0.0632 - accuracy: 0.9757 - val_loss: 0.1006 - val_accuracy: 0.9587 - 209ms/epoch - 7ms/step
# Epoch 140/300
# 30/30 - 0s - loss: 0.0746 - accuracy: 0.9741 - val_loss: 0.1435 - val_accuracy: 0.9444 - 216ms/epoch - 7ms/step
# Epoch 141/300
# 30/30 - 0s - loss: 0.0659 - accuracy: 0.9788 - val_loss: 0.0942 - val_accuracy: 0.9675 - 211ms/epoch - 7ms/step
# Epoch 142/300
# 30/30 - 0s - loss: 0.0600 - accuracy: 0.9767 - val_loss: 0.1185 - val_accuracy: 0.9516 - 229ms/epoch - 8ms/step
# Epoch 143/300
# 30/30 - 0s - loss: 0.0487 - accuracy: 0.9810 - val_loss: 0.0994 - val_accuracy: 0.9603 - 221ms/epoch - 7ms/step
# Epoch 144/300
# 30/30 - 0s - loss: 0.0520 - accuracy: 0.9788 - val_loss: 0.1001 - val_accuracy: 0.9611 - 201ms/epoch - 7ms/step
# Epoch 145/300
# 30/30 - 0s - loss: 0.0654 - accuracy: 0.9751 - val_loss: 0.1196 - val_accuracy: 0.9484 - 228ms/epoch - 8ms/step
# Epoch 146/300
# 30/30 - 0s - loss: 0.0624 - accuracy: 0.9746 - val_loss: 0.1335 - val_accuracy: 0.9468 - 221ms/epoch - 7ms/step
# Epoch 147/300
# 30/30 - 0s - loss: 0.0475 - accuracy: 0.9815 - val_loss: 0.1097 - val_accuracy: 0.9611 - 215ms/epoch - 7ms/step
# Epoch 148/300
# 30/30 - 0s - loss: 0.0512 - accuracy: 0.9820 - val_loss: 0.1293 - val_accuracy: 0.9484 - 250ms/epoch - 8ms/step
# Epoch 149/300
# 30/30 - 0s - loss: 0.0532 - accuracy: 0.9799 - val_loss: 0.1223 - val_accuracy: 0.9587 - 242ms/epoch - 8ms/step
# Epoch 150/300
# 30/30 - 0s - loss: 0.0568 - accuracy: 0.9778 - val_loss: 0.1139 - val_accuracy: 0.9587 - 213ms/epoch - 7ms/step
# Epoch 151/300
# 30/30 - 0s - loss: 0.0549 - accuracy: 0.9783 - val_loss: 0.1338 - val_accuracy: 0.9500 - 233ms/epoch - 8ms/step
# Epoch 152/300
# 30/30 - 0s - loss: 0.0598 - accuracy: 0.9783 - val_loss: 0.1567 - val_accuracy: 0.9468 - 245ms/epoch - 8ms/step
# Epoch 153/300
# 30/30 - 0s - loss: 0.0435 - accuracy: 0.9852 - val_loss: 0.1253 - val_accuracy: 0.9540 - 235ms/epoch - 8ms/step
# Epoch 154/300
# 30/30 - 0s - loss: 0.0507 - accuracy: 0.9815 - val_loss: 0.1114 - val_accuracy: 0.9595 - 248ms/epoch - 8ms/step
# Epoch 155/300
# 30/30 - 0s - loss: 0.0511 - accuracy: 0.9810 - val_loss: 0.0888 - val_accuracy: 0.9675 - 230ms/epoch - 8ms/step
# Epoch 156/300
# 30/30 - 0s - loss: 0.0591 - accuracy: 0.9799 - val_loss: 0.0982 - val_accuracy: 0.9714 - 233ms/epoch - 8ms/step
# Epoch 157/300
# 30/30 - 0s - loss: 0.0477 - accuracy: 0.9810 - val_loss: 0.1540 - val_accuracy: 0.9405 - 216ms/epoch - 7ms/step
# Epoch 158/300
# 30/30 - 0s - loss: 0.0494 - accuracy: 0.9831 - val_loss: 0.1139 - val_accuracy: 0.9571 - 211ms/epoch - 7ms/step
# Epoch 159/300
# 30/30 - 0s - loss: 0.0383 - accuracy: 0.9868 - val_loss: 0.1318 - val_accuracy: 0.9548 - 223ms/epoch - 7ms/step
# Epoch 160/300
# 30/30 - 0s - loss: 0.0459 - accuracy: 0.9825 - val_loss: 0.0800 - val_accuracy: 0.9738 - 230ms/epoch - 8ms/step
# Epoch 161/300
# 30/30 - 0s - loss: 0.0626 - accuracy: 0.9767 - val_loss: 0.1281 - val_accuracy: 0.9571 - 225ms/epoch - 8ms/step
# Epoch 162/300
# 30/30 - 0s - loss: 0.0556 - accuracy: 0.9778 - val_loss: 0.1007 - val_accuracy: 0.9540 - 214ms/epoch - 7ms/step
# Epoch 163/300
# 30/30 - 0s - loss: 0.0508 - accuracy: 0.9836 - val_loss: 0.1113 - val_accuracy: 0.9563 - 223ms/epoch - 7ms/step
# Epoch 164/300
# 30/30 - 0s - loss: 0.0560 - accuracy: 0.9794 - val_loss: 0.1032 - val_accuracy: 0.9643 - 219ms/epoch - 7ms/step
# Epoch 165/300
# 30/30 - 0s - loss: 0.0425 - accuracy: 0.9847 - val_loss: 0.1014 - val_accuracy: 0.9659 - 213ms/epoch - 7ms/step
# Epoch 166/300
# 30/30 - 0s - loss: 0.0488 - accuracy: 0.9815 - val_loss: 0.1205 - val_accuracy: 0.9532 - 221ms/epoch - 7ms/step
# Epoch 167/300
# 30/30 - 0s - loss: 0.0593 - accuracy: 0.9751 - val_loss: 0.1081 - val_accuracy: 0.9643 - 247ms/epoch - 8ms/step
# Epoch 168/300
# 30/30 - 0s - loss: 0.0512 - accuracy: 0.9820 - val_loss: 0.1079 - val_accuracy: 0.9635 - 246ms/epoch - 8ms/step
# Epoch 169/300
# 30/30 - 0s - loss: 0.0466 - accuracy: 0.9831 - val_loss: 0.1046 - val_accuracy: 0.9611 - 258ms/epoch - 9ms/step
# Epoch 170/300
# 30/30 - 0s - loss: 0.0379 - accuracy: 0.9868 - val_loss: 0.0901 - val_accuracy: 0.9651 - 224ms/epoch - 7ms/step
# Epoch 171/300
# 30/30 - 0s - loss: 0.0420 - accuracy: 0.9862 - val_loss: 0.0979 - val_accuracy: 0.9651 - 227ms/epoch - 8ms/step
# Epoch 172/300
# 30/30 - 0s - loss: 0.0460 - accuracy: 0.9841 - val_loss: 0.0877 - val_accuracy: 0.9675 - 220ms/epoch - 7ms/step
# Epoch 173/300
# 30/30 - 0s - loss: 0.0410 - accuracy: 0.9889 - val_loss: 0.0964 - val_accuracy: 0.9675 - 225ms/epoch - 7ms/step
# Epoch 174/300
# 30/30 - 0s - loss: 0.0417 - accuracy: 0.9836 - val_loss: 0.0734 - val_accuracy: 0.9770 - 253ms/epoch - 8ms/step
# Epoch 175/300
# 30/30 - 0s - loss: 0.0469 - accuracy: 0.9825 - val_loss: 0.0846 - val_accuracy: 0.9714 - 237ms/epoch - 8ms/step
# Epoch 176/300
# 30/30 - 0s - loss: 0.0406 - accuracy: 0.9857 - val_loss: 0.1034 - val_accuracy: 0.9651 - 215ms/epoch - 7ms/step
# Epoch 177/300
# 30/30 - 0s - loss: 0.0423 - accuracy: 0.9841 - val_loss: 0.0894 - val_accuracy: 0.9619 - 228ms/epoch - 8ms/step
# Epoch 178/300
# 30/30 - 0s - loss: 0.0391 - accuracy: 0.9852 - val_loss: 0.0836 - val_accuracy: 0.9683 - 221ms/epoch - 7ms/step
# Epoch 179/300
# 30/30 - 0s - loss: 0.0359 - accuracy: 0.9905 - val_loss: 0.1004 - val_accuracy: 0.9627 - 234ms/epoch - 8ms/step
# Epoch 180/300
# 30/30 - 0s - loss: 0.0386 - accuracy: 0.9857 - val_loss: 0.0948 - val_accuracy: 0.9643 - 223ms/epoch - 7ms/step
# Epoch 181/300
# 30/30 - 0s - loss: 0.0423 - accuracy: 0.9884 - val_loss: 0.1026 - val_accuracy: 0.9659 - 229ms/epoch - 8ms/step
# Epoch 182/300
# 30/30 - 0s - loss: 0.0468 - accuracy: 0.9841 - val_loss: 0.0819 - val_accuracy: 0.9730 - 216ms/epoch - 7ms/step
# Epoch 183/300
# 30/30 - 0s - loss: 0.0438 - accuracy: 0.9841 - val_loss: 0.0687 - val_accuracy: 0.9762 - 208ms/epoch - 7ms/step
# Epoch 184/300
# 30/30 - 0s - loss: 0.0497 - accuracy: 0.9804 - val_loss: 0.0918 - val_accuracy: 0.9698 - 207ms/epoch - 7ms/step
# Epoch 185/300
# 30/30 - 0s - loss: 0.0593 - accuracy: 0.9778 - val_loss: 0.0805 - val_accuracy: 0.9754 - 203ms/epoch - 7ms/step
# Epoch 186/300
# 30/30 - 0s - loss: 0.0573 - accuracy: 0.9762 - val_loss: 0.1155 - val_accuracy: 0.9603 - 211ms/epoch - 7ms/step
# Epoch 187/300
# 30/30 - 0s - loss: 0.0602 - accuracy: 0.9757 - val_loss: 0.0746 - val_accuracy: 0.9770 - 213ms/epoch - 7ms/step
# Epoch 188/300
# 30/30 - 0s - loss: 0.0388 - accuracy: 0.9857 - val_loss: 0.0727 - val_accuracy: 0.9754 - 205ms/epoch - 7ms/step
# Epoch 189/300
# 30/30 - 0s - loss: 0.0504 - accuracy: 0.9788 - val_loss: 0.1271 - val_accuracy: 0.9548 - 211ms/epoch - 7ms/step
# Epoch 190/300
# 30/30 - 0s - loss: 0.0476 - accuracy: 0.9794 - val_loss: 0.0870 - val_accuracy: 0.9651 - 213ms/epoch - 7ms/step
# Epoch 191/300
# 30/30 - 0s - loss: 0.0412 - accuracy: 0.9868 - val_loss: 0.1196 - val_accuracy: 0.9540 - 224ms/epoch - 7ms/step
# Epoch 192/300
# 30/30 - 0s - loss: 0.0359 - accuracy: 0.9878 - val_loss: 0.1135 - val_accuracy: 0.9587 - 206ms/epoch - 7ms/step
# Epoch 193/300
# 30/30 - 0s - loss: 0.0367 - accuracy: 0.9868 - val_loss: 0.0811 - val_accuracy: 0.9722 - 228ms/epoch - 8ms/step
# Epoch 194/300
# 30/30 - 0s - loss: 0.0359 - accuracy: 0.9868 - val_loss: 0.0806 - val_accuracy: 0.9778 - 220ms/epoch - 7ms/step
# Epoch 195/300
# 30/30 - 0s - loss: 0.0395 - accuracy: 0.9884 - val_loss: 0.0888 - val_accuracy: 0.9659 - 219ms/epoch - 7ms/step
# Epoch 196/300
# 30/30 - 0s - loss: 0.0352 - accuracy: 0.9873 - val_loss: 0.0937 - val_accuracy: 0.9619 - 215ms/epoch - 7ms/step
# Epoch 197/300
# 30/30 - 0s - loss: 0.0439 - accuracy: 0.9831 - val_loss: 0.0943 - val_accuracy: 0.9643 - 209ms/epoch - 7ms/step
# Epoch 198/300
# 30/30 - 0s - loss: 0.0317 - accuracy: 0.9910 - val_loss: 0.1237 - val_accuracy: 0.9508 - 226ms/epoch - 8ms/step
# Epoch 199/300
# 30/30 - 0s - loss: 0.0389 - accuracy: 0.9884 - val_loss: 0.1073 - val_accuracy: 0.9611 - 227ms/epoch - 8ms/step
# Epoch 200/300
# 30/30 - 0s - loss: 0.0377 - accuracy: 0.9847 - val_loss: 0.1271 - val_accuracy: 0.9524 - 225ms/epoch - 8ms/step
# Epoch 201/300
# 30/30 - 0s - loss: 0.0384 - accuracy: 0.9873 - val_loss: 0.1021 - val_accuracy: 0.9587 - 225ms/epoch - 8ms/step
# Epoch 202/300
# 30/30 - 0s - loss: 0.0365 - accuracy: 0.9873 - val_loss: 0.0907 - val_accuracy: 0.9714 - 205ms/epoch - 7ms/step
# Epoch 203/300
# 30/30 - 0s - loss: 0.0311 - accuracy: 0.9894 - val_loss: 0.0807 - val_accuracy: 0.9722 - 213ms/epoch - 7ms/step
# Epoch 204/300
# 30/30 - 0s - loss: 0.0350 - accuracy: 0.9878 - val_loss: 0.0990 - val_accuracy: 0.9643 - 212ms/epoch - 7ms/step
# Epoch 205/300
# 30/30 - 0s - loss: 0.0322 - accuracy: 0.9889 - val_loss: 0.0889 - val_accuracy: 0.9651 - 231ms/epoch - 8ms/step
# Epoch 206/300
# 30/30 - 0s - loss: 0.0330 - accuracy: 0.9873 - val_loss: 0.0727 - val_accuracy: 0.9762 - 225ms/epoch - 8ms/step
# Epoch 207/300
# 30/30 - 0s - loss: 0.0385 - accuracy: 0.9847 - val_loss: 0.0887 - val_accuracy: 0.9675 - 207ms/epoch - 7ms/step
# Epoch 208/300
# 30/30 - 0s - loss: 0.0357 - accuracy: 0.9889 - val_loss: 0.0868 - val_accuracy: 0.9698 - 230ms/epoch - 8ms/step
# Epoch 209/300
# 30/30 - 0s - loss: 0.0351 - accuracy: 0.9862 - val_loss: 0.0770 - val_accuracy: 0.9746 - 224ms/epoch - 7ms/step
# Epoch 210/300
# 30/30 - 0s - loss: 0.0362 - accuracy: 0.9868 - val_loss: 0.0959 - val_accuracy: 0.9651 - 220ms/epoch - 7ms/step
# Epoch 211/300
# 30/30 - 0s - loss: 0.0257 - accuracy: 0.9915 - val_loss: 0.0953 - val_accuracy: 0.9659 - 214ms/epoch - 7ms/step
# Epoch 212/300
# 30/30 - 0s - loss: 0.0310 - accuracy: 0.9894 - val_loss: 0.1574 - val_accuracy: 0.9476 - 224ms/epoch - 7ms/step
# Epoch 213/300
# 30/30 - 0s - loss: 0.0333 - accuracy: 0.9873 - val_loss: 0.0981 - val_accuracy: 0.9651 - 209ms/epoch - 7ms/step
# Epoch 214/300
# 30/30 - 0s - loss: 0.0293 - accuracy: 0.9905 - val_loss: 0.0709 - val_accuracy: 0.9802 - 232ms/epoch - 8ms/step
# Epoch 215/300
# 30/30 - 0s - loss: 0.0342 - accuracy: 0.9905 - val_loss: 0.0960 - val_accuracy: 0.9667 - 219ms/epoch - 7ms/step
# Epoch 216/300
# 30/30 - 0s - loss: 0.0536 - accuracy: 0.9794 - val_loss: 0.1042 - val_accuracy: 0.9635 - 217ms/epoch - 7ms/step
# Epoch 217/300
# 30/30 - 0s - loss: 0.0506 - accuracy: 0.9804 - val_loss: 0.0820 - val_accuracy: 0.9738 - 220ms/epoch - 7ms/step
# Epoch 218/300
# 30/30 - 0s - loss: 0.0422 - accuracy: 0.9857 - val_loss: 0.1411 - val_accuracy: 0.9476 - 244ms/epoch - 8ms/step
# Epoch 219/300
# 30/30 - 0s - loss: 0.0285 - accuracy: 0.9905 - val_loss: 0.0905 - val_accuracy: 0.9667 - 216ms/epoch - 7ms/step
# Epoch 220/300
# 30/30 - 0s - loss: 0.0242 - accuracy: 0.9937 - val_loss: 0.1144 - val_accuracy: 0.9627 - 220ms/epoch - 7ms/step
# Epoch 221/300
# 30/30 - 0s - loss: 0.0282 - accuracy: 0.9894 - val_loss: 0.0765 - val_accuracy: 0.9762 - 241ms/epoch - 8ms/step
# Epoch 222/300
# 30/30 - 0s - loss: 0.0343 - accuracy: 0.9884 - val_loss: 0.0902 - val_accuracy: 0.9714 - 229ms/epoch - 8ms/step
# Epoch 223/300
# 30/30 - 0s - loss: 0.0396 - accuracy: 0.9862 - val_loss: 0.0846 - val_accuracy: 0.9754 - 224ms/epoch - 7ms/step
# Epoch 224/300
# 30/30 - 0s - loss: 0.0396 - accuracy: 0.9862 - val_loss: 0.1039 - val_accuracy: 0.9611 - 229ms/epoch - 8ms/step
# Epoch 225/300
# 30/30 - 0s - loss: 0.0393 - accuracy: 0.9852 - val_loss: 0.1481 - val_accuracy: 0.9437 - 242ms/epoch - 8ms/step
# Epoch 226/300
# 30/30 - 0s - loss: 0.0409 - accuracy: 0.9884 - val_loss: 0.0817 - val_accuracy: 0.9722 - 275ms/epoch - 9ms/step
# Epoch 227/300
# 30/30 - 0s - loss: 0.0263 - accuracy: 0.9947 - val_loss: 0.1047 - val_accuracy: 0.9595 - 230ms/epoch - 8ms/step
# Epoch 228/300
# 30/30 - 0s - loss: 0.0257 - accuracy: 0.9931 - val_loss: 0.0691 - val_accuracy: 0.9802 - 242ms/epoch - 8ms/step
# Epoch 229/300
# 30/30 - 0s - loss: 0.0291 - accuracy: 0.9910 - val_loss: 0.0684 - val_accuracy: 0.9762 - 206ms/epoch - 7ms/step
# Epoch 230/300
# 30/30 - 0s - loss: 0.0232 - accuracy: 0.9915 - val_loss: 0.0712 - val_accuracy: 0.9762 - 223ms/epoch - 7ms/step
# Epoch 231/300
# 30/30 - 0s - loss: 0.0283 - accuracy: 0.9910 - val_loss: 0.0953 - val_accuracy: 0.9698 - 242ms/epoch - 8ms/step
# Epoch 232/300
# 30/30 - 0s - loss: 0.0271 - accuracy: 0.9910 - val_loss: 0.0837 - val_accuracy: 0.9698 - 214ms/epoch - 7ms/step
# Epoch 233/300
# 30/30 - 0s - loss: 0.0289 - accuracy: 0.9910 - val_loss: 0.0827 - val_accuracy: 0.9722 - 230ms/epoch - 8ms/step
# Epoch 234/300
# 30/30 - 0s - loss: 0.0350 - accuracy: 0.9889 - val_loss: 0.0907 - val_accuracy: 0.9698 - 232ms/epoch - 8ms/step
# Epoch 235/300
# 30/30 - 0s - loss: 0.0266 - accuracy: 0.9899 - val_loss: 0.0775 - val_accuracy: 0.9762 - 227ms/epoch - 8ms/step
# Epoch 236/300
# 30/30 - 0s - loss: 0.0360 - accuracy: 0.9873 - val_loss: 0.0892 - val_accuracy: 0.9714 - 221ms/epoch - 7ms/step
# Epoch 237/300
# 30/30 - 0s - loss: 0.0339 - accuracy: 0.9884 - val_loss: 0.1079 - val_accuracy: 0.9667 - 218ms/epoch - 7ms/step
# Epoch 238/300
# 30/30 - 0s - loss: 0.0307 - accuracy: 0.9868 - val_loss: 0.1665 - val_accuracy: 0.9437 - 222ms/epoch - 7ms/step
# Epoch 239/300
# 30/30 - 0s - loss: 0.0330 - accuracy: 0.9894 - val_loss: 0.1147 - val_accuracy: 0.9611 - 217ms/epoch - 7ms/step
# Epoch 240/300
# 30/30 - 0s - loss: 0.0376 - accuracy: 0.9857 - val_loss: 0.1542 - val_accuracy: 0.9429 - 234ms/epoch - 8ms/step
# Epoch 241/300
# 30/30 - 0s - loss: 0.0266 - accuracy: 0.9905 - val_loss: 0.1219 - val_accuracy: 0.9603 - 237ms/epoch - 8ms/step
# Epoch 242/300
# 30/30 - 0s - loss: 0.0314 - accuracy: 0.9905 - val_loss: 0.0870 - val_accuracy: 0.9675 - 229ms/epoch - 8ms/step
# Epoch 243/300
# 30/30 - 0s - loss: 0.0305 - accuracy: 0.9868 - val_loss: 0.0756 - val_accuracy: 0.9754 - 221ms/epoch - 7ms/step
# Epoch 244/300
# 30/30 - 0s - loss: 0.0281 - accuracy: 0.9905 - val_loss: 0.1090 - val_accuracy: 0.9571 - 217ms/epoch - 7ms/step
# Epoch 245/300
# 30/30 - 0s - loss: 0.0301 - accuracy: 0.9899 - val_loss: 0.0659 - val_accuracy: 0.9786 - 217ms/epoch - 7ms/step
# Epoch 246/300
# 30/30 - 0s - loss: 0.0215 - accuracy: 0.9942 - val_loss: 0.0812 - val_accuracy: 0.9738 - 205ms/epoch - 7ms/step
# Epoch 247/300
# 30/30 - 0s - loss: 0.0274 - accuracy: 0.9910 - val_loss: 0.0733 - val_accuracy: 0.9770 - 224ms/epoch - 7ms/step
# Epoch 248/300
# 30/30 - 0s - loss: 0.0216 - accuracy: 0.9942 - val_loss: 0.0873 - val_accuracy: 0.9698 - 219ms/epoch - 7ms/step
# Epoch 249/300
# 30/30 - 0s - loss: 0.0267 - accuracy: 0.9894 - val_loss: 0.1246 - val_accuracy: 0.9587 - 237ms/epoch - 8ms/step
# Epoch 250/300
# 30/30 - 0s - loss: 0.0271 - accuracy: 0.9910 - val_loss: 0.1134 - val_accuracy: 0.9595 - 220ms/epoch - 7ms/step
# Epoch 251/300
# 30/30 - 0s - loss: 0.0227 - accuracy: 0.9937 - val_loss: 0.0807 - val_accuracy: 0.9706 - 237ms/epoch - 8ms/step
# Epoch 252/300
# 30/30 - 0s - loss: 0.0367 - accuracy: 0.9899 - val_loss: 0.0776 - val_accuracy: 0.9778 - 222ms/epoch - 7ms/step
# Epoch 253/300
# 30/30 - 0s - loss: 0.0309 - accuracy: 0.9878 - val_loss: 0.0900 - val_accuracy: 0.9730 - 218ms/epoch - 7ms/step
# Epoch 254/300
# 30/30 - 0s - loss: 0.0219 - accuracy: 0.9921 - val_loss: 0.0662 - val_accuracy: 0.9778 - 255ms/epoch - 9ms/step
# Epoch 255/300
# 30/30 - 0s - loss: 0.0272 - accuracy: 0.9910 - val_loss: 0.0627 - val_accuracy: 0.9825 - 247ms/epoch - 8ms/step
# Epoch 256/300
# 30/30 - 0s - loss: 0.0245 - accuracy: 0.9921 - val_loss: 0.0647 - val_accuracy: 0.9794 - 239ms/epoch - 8ms/step
# Epoch 257/300
# 30/30 - 0s - loss: 0.0240 - accuracy: 0.9910 - val_loss: 0.0801 - val_accuracy: 0.9714 - 227ms/epoch - 8ms/step
# Epoch 258/300
# 30/30 - 0s - loss: 0.0207 - accuracy: 0.9931 - val_loss: 0.0695 - val_accuracy: 0.9786 - 217ms/epoch - 7ms/step
# Epoch 259/300
# 30/30 - 0s - loss: 0.0193 - accuracy: 0.9931 - val_loss: 0.0794 - val_accuracy: 0.9746 - 213ms/epoch - 7ms/step
# Epoch 260/300
# 30/30 - 0s - loss: 0.0313 - accuracy: 0.9862 - val_loss: 0.0851 - val_accuracy: 0.9754 - 212ms/epoch - 7ms/step
# Epoch 261/300
# 30/30 - 0s - loss: 0.0295 - accuracy: 0.9905 - val_loss: 0.0723 - val_accuracy: 0.9762 - 214ms/epoch - 7ms/step
# Epoch 262/300
# 30/30 - 0s - loss: 0.0343 - accuracy: 0.9857 - val_loss: 0.1066 - val_accuracy: 0.9683 - 222ms/epoch - 7ms/step
# Epoch 263/300
# 30/30 - 0s - loss: 0.0261 - accuracy: 0.9910 - val_loss: 0.0806 - val_accuracy: 0.9738 - 237ms/epoch - 8ms/step
# Epoch 264/300
# 30/30 - 0s - loss: 0.0263 - accuracy: 0.9905 - val_loss: 0.0740 - val_accuracy: 0.9794 - 226ms/epoch - 8ms/step
# Epoch 265/300
# 30/30 - 0s - loss: 0.0191 - accuracy: 0.9937 - val_loss: 0.0742 - val_accuracy: 0.9762 - 223ms/epoch - 7ms/step
# Epoch 266/300
# 30/30 - 0s - loss: 0.0237 - accuracy: 0.9910 - val_loss: 0.0678 - val_accuracy: 0.9794 - 212ms/epoch - 7ms/step
# Epoch 267/300
# 30/30 - 0s - loss: 0.0234 - accuracy: 0.9910 - val_loss: 0.0609 - val_accuracy: 0.9849 - 215ms/epoch - 7ms/step
# Epoch 268/300
# 30/30 - 0s - loss: 0.0280 - accuracy: 0.9899 - val_loss: 0.0850 - val_accuracy: 0.9730 - 235ms/epoch - 8ms/step
# Epoch 269/300
# 30/30 - 0s - loss: 0.0258 - accuracy: 0.9899 - val_loss: 0.0682 - val_accuracy: 0.9778 - 229ms/epoch - 8ms/step
# Epoch 270/300
# 30/30 - 0s - loss: 0.0258 - accuracy: 0.9894 - val_loss: 0.0802 - val_accuracy: 0.9722 - 233ms/epoch - 8ms/step
# Epoch 271/300
# 30/30 - 0s - loss: 0.0254 - accuracy: 0.9915 - val_loss: 0.0875 - val_accuracy: 0.9730 - 224ms/epoch - 7ms/step
# Epoch 272/300
# 30/30 - 0s - loss: 0.0303 - accuracy: 0.9878 - val_loss: 0.0899 - val_accuracy: 0.9730 - 218ms/epoch - 7ms/step
# Epoch 273/300
# 30/30 - 0s - loss: 0.0329 - accuracy: 0.9884 - val_loss: 0.1015 - val_accuracy: 0.9683 - 224ms/epoch - 7ms/step
# Epoch 274/300
# 30/30 - 0s - loss: 0.0194 - accuracy: 0.9952 - val_loss: 0.1655 - val_accuracy: 0.9484 - 225ms/epoch - 7ms/step
# Epoch 275/300
# 30/30 - 0s - loss: 0.0177 - accuracy: 0.9937 - val_loss: 0.0916 - val_accuracy: 0.9714 - 240ms/epoch - 8ms/step
# Epoch 276/300
# 30/30 - 0s - loss: 0.0250 - accuracy: 0.9905 - val_loss: 0.0762 - val_accuracy: 0.9778 - 241ms/epoch - 8ms/step
# Epoch 277/300
# 30/30 - 0s - loss: 0.0250 - accuracy: 0.9931 - val_loss: 0.0753 - val_accuracy: 0.9754 - 216ms/epoch - 7ms/step
# Epoch 278/300
# 30/30 - 0s - loss: 0.0306 - accuracy: 0.9884 - val_loss: 0.1215 - val_accuracy: 0.9635 - 228ms/epoch - 8ms/step
# Epoch 279/300
# 30/30 - 0s - loss: 0.0199 - accuracy: 0.9942 - val_loss: 0.0738 - val_accuracy: 0.9762 - 230ms/epoch - 8ms/step
# Epoch 280/300
# 30/30 - 0s - loss: 0.0297 - accuracy: 0.9894 - val_loss: 0.0734 - val_accuracy: 0.9762 - 217ms/epoch - 7ms/step
# Epoch 281/300
# 30/30 - 0s - loss: 0.0270 - accuracy: 0.9921 - val_loss: 0.0632 - val_accuracy: 0.9778 - 220ms/epoch - 7ms/step
# Epoch 282/300
# 30/30 - 0s - loss: 0.0379 - accuracy: 0.9868 - val_loss: 0.0709 - val_accuracy: 0.9778 - 229ms/epoch - 8ms/step
# Epoch 283/300
# 30/30 - 0s - loss: 0.0326 - accuracy: 0.9868 - val_loss: 0.0774 - val_accuracy: 0.9762 - 221ms/epoch - 7ms/step
# Epoch 284/300
# 30/30 - 0s - loss: 0.0242 - accuracy: 0.9910 - val_loss: 0.0584 - val_accuracy: 0.9833 - 217ms/epoch - 7ms/step
# Epoch 285/300
# 30/30 - 0s - loss: 0.0249 - accuracy: 0.9905 - val_loss: 0.0805 - val_accuracy: 0.9714 - 217ms/epoch - 7ms/step
# Epoch 286/300
# 30/30 - 0s - loss: 0.0217 - accuracy: 0.9915 - val_loss: 0.0588 - val_accuracy: 0.9802 - 234ms/epoch - 8ms/step
# Epoch 287/300
# 30/30 - 0s - loss: 0.0238 - accuracy: 0.9894 - val_loss: 0.0685 - val_accuracy: 0.9778 - 229ms/epoch - 8ms/step
# Epoch 288/300
# 30/30 - 0s - loss: 0.0222 - accuracy: 0.9921 - val_loss: 0.0889 - val_accuracy: 0.9714 - 217ms/epoch - 7ms/step
# Epoch 289/300
# 30/30 - 0s - loss: 0.0186 - accuracy: 0.9937 - val_loss: 0.0706 - val_accuracy: 0.9786 - 222ms/epoch - 7ms/step
# Epoch 290/300
# 30/30 - 0s - loss: 0.0197 - accuracy: 0.9952 - val_loss: 0.0620 - val_accuracy: 0.9817 - 217ms/epoch - 7ms/step
# Epoch 291/300
# 30/30 - 0s - loss: 0.0211 - accuracy: 0.9963 - val_loss: 0.0655 - val_accuracy: 0.9762 - 212ms/epoch - 7ms/step
# Epoch 292/300
# 30/30 - 0s - loss: 0.0182 - accuracy: 0.9947 - val_loss: 0.0866 - val_accuracy: 0.9730 - 217ms/epoch - 7ms/step
# Epoch 293/300
# 30/30 - 0s - loss: 0.0306 - accuracy: 0.9868 - val_loss: 0.0871 - val_accuracy: 0.9754 - 230ms/epoch - 8ms/step
# Epoch 294/300
# 30/30 - 0s - loss: 0.0272 - accuracy: 0.9894 - val_loss: 0.0650 - val_accuracy: 0.9794 - 214ms/epoch - 7ms/step
# Epoch 295/300
# 30/30 - 0s - loss: 0.0207 - accuracy: 0.9937 - val_loss: 0.0685 - val_accuracy: 0.9778 - 217ms/epoch - 7ms/step
# Epoch 296/300
# 30/30 - 0s - loss: 0.0281 - accuracy: 0.9878 - val_loss: 0.0891 - val_accuracy: 0.9730 - 228ms/epoch - 8ms/step
# Epoch 297/300
# 30/30 - 0s - loss: 0.0189 - accuracy: 0.9947 - val_loss: 0.0994 - val_accuracy: 0.9667 - 226ms/epoch - 8ms/step
# Epoch 298/300
# 30/30 - 0s - loss: 0.0276 - accuracy: 0.9899 - val_loss: 0.0830 - val_accuracy: 0.9746 - 212ms/epoch - 7ms/step
# Epoch 299/300
# 30/30 - 0s - loss: 0.0192 - accuracy: 0.9947 - val_loss: 0.0718 - val_accuracy: 0.9738 - 215ms/epoch - 7ms/step
# Epoch 300/300
# 30/30 - 0s - loss: 0.0157 - accuracy: 0.9942 - val_loss: 0.0950 - val_accuracy: 0.9659 - 233ms/epoch - 8ms/step

# %%
plt.figure(figsize=(7, 10))
metric = "accuracy"
plt.subplot(2, 1, 1)
plt.plot(history[metric])
plt.plot(history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")

plt.subplot(2, 1, 2)
metric = "loss"
plt.plot(history[metric])
plt.plot(history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()

# %%
# Saving current model
import tensorflow as tf
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
with open("model_v2rnn_20241209.tflite", "wb") as f:
    f.write(tflite_model)


# save model weights
model.save_weights("model_v2rnn_20241209.h5")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\User\AppData\Local\Temp\tmprltm7xoo\assets
# INFO:tensorflow:Assets written to: C:\Users\User\AppData\Local\Temp\tmprltm7xoo\assets

# %%
# Model Loader:

model = ts_cnn()
model.load_weights("model_v2rnn_20241209.h5")

# %%
idx = np.random.permutation(len(x))
x = x[idx]
y = y[idx]

print(f'First 5 samples: {y[:5]}') # see a couple of examples
np.argmax(y, axis=1)[:5]

# find how many positive and negative samples are in the dataset
print(f'positive: {np.sum(np.argmax(y, axis=1) == 0)}')
print(f'negative: {np.sum(np.argmax(y, axis=1) == 1)}')

# y_val = np.reshape(y, (len(y),))
y_val = y.argmax(axis=1)
y_pred = np.argmax(model.predict([x[:,0], x[:,1]]), axis=1)

# find how many positive and negative samples are in the predicted dataset
print(f'prediction_negative: {np.sum(y_pred == 0)}')
print(f'prediction_slip: {np.sum(y_pred == 1)}')
print(f'prediction_trip: {np.sum(y_pred == 2)}')
# Out:
# First 5 samples: [[0. 1. 0.]
#  [1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]
#  [0. 1. 0.]]
# positive: 1656
# negative: 762
# 99/99 [==============================] - 0s 2ms/step
# prediction_negative: 1649
# prediction_slip: 733
# prediction_trip: 768

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
#Create confusion matrix and normalizes it over predicted (columns)
result = confusion_matrix(y_val, y_pred, labels=[0,1,2])

# %%
result
# Out:
# array([[1648,    4,    4],
#        [   1,  727,   34],
#        [   0,    2,  730]], dtype=int64)

# %%
# Matrix with labels
group_names = ['No Incident','False Slip','False Trip',
                'False No Incident', 'True Slip', 'False Trip',
                'False No Incident', 'False Slip', 'True Trip']
group_counts = ["{0:0.0f}".format(value) for value in result.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in result.flatten()/np.sum(result)]

labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(3,3)

ax = sns.heatmap(result, annot=labels, fmt='', cmap='Blues')
ax.set_title('Model Validation Confusion Matrix\n\n')
ax.set_xlabel('\nPredicted')
ax.set_ylabel('Actual')

## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(['No Incident','Slip', 'Trip'])
ax.yaxis.set_ticklabels(['No Incident','Slip', 'Trip'])

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
# Matrix with labels
group_names = [
    "No Incident",
    "False Slip",
    "False Trip",
    "False No Incident",
    "True Slip",
    "False Slip",
    "False No Incident",
    "False Slip",
    "True Trip",
]
group_counts = ["{0:0.0f}".format(value) for value in result.flatten()]
group_percentages = [
    "{0:.2%}".format(value) for value in result.flatten() / np.sum(result)
]

labels = [
    f"{v1}\n{v2}\n{v3}"
    for v1, v2, v3 in zip(group_names, group_counts, group_percentages)
]
labels = np.asarray(labels).reshape(3, 3)

ax = sns.heatmap(result, annot=labels, fmt="", cmap="Blues")
ax.set_title("Model Validation Confusion Matrix\n\n")
ax.set_xlabel("\nPredicted")
ax.set_ylabel("Actual")
## Ticket labels - List must be in alphabetical order
ax.xaxis.set_ticklabels(["No Incident", "Slip", "Trip"])
ax.yaxis.set_ticklabels(["No Incident", "Slip", "Trip"])

## Display the visualization of the Confusion Matrix.
plt.show()
