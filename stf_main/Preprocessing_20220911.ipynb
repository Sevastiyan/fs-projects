# %%
import numpy as np
import os
from utils.data_loader import convert_signal, load_data
from utils.slice import slice_data
from utils.plots import plot_data

# %% [markdown]
# # Plotting the data

# %%
def plot_incidents():
    root = 'data/22-08-16/'
    file_list = []
    filenames = []
    for subdir in os.listdir(root):
        print(subdir)
        if subdir == "Base Case":
            continue

        for p, s, f in os.walk(os.path.join(root, subdir)):
            for filename in f: 
                file_list.append(os.path.join(root, subdir, filename).replace("\\","/"))
                filenames.append(filename)
                
    data = load_data(file_list)
    for i in range(len(data)): 
        sample = data[i]
        signal = convert_signal(sample, type='acc_total')
        signal = signal.to_numpy()

        sliced = slice_data(signal, [45, 245])

        plot_data([signal, sliced], [45, 245], subdir='Aug-16', title=filenames[i], save=True)

# %%
plot_incidents()

# %% [markdown]
# # Data preparation:

# %%
# Move borders in plot_data function if required, requires 10 seconds of data 
import numpy as np
from utils.data_loader import convert_signal, load_data
from utils.slice import slice_data

path = f"./data/processed/"
root = 'data/22-08-16/'

def incidents():
    START = 50
    END = 60
    STEP = 10

    file_list = []
    for subdir in os.listdir(root):
        if subdir in ['Base Case', 'Base Case Walking', 'no_incidents']:
            continue

        for p, s, f in os.walk(os.path.join(root, subdir)):
            for filename in f: 
                file_list.append(os.path.join(root, subdir, filename))

    data = load_data(file_list)

    acc_results = []
    gyro_results = []

    for sample in data: 
        acc_signal = convert_signal(sample, type='acc_total').to_numpy()
        gyro_signal = convert_signal(sample, type='gyro_total').to_numpy()
        for i in range(START, END, STEP): # overlap samples
            x_acc = acc_signal[i : i+200]
            x_gyro = gyro_signal[i : i+200]
            if len(x_acc) < 200:
                x_acc = np.resize(x_acc, (200)) 
            if len(x_gyro) < 200:
                x_gyro = np.resize(x_gyro, (200)) 

            acc_results.append(x_acc.tolist())
            gyro_results.append(x_gyro.tolist())

    # ! Add pressure sensors
        
    save_file(np.asarray(acc_results), path, 'incidents_august_acc')
    save_file(np.asarray(gyro_results), path, 'incidents_august_gyro')



def save_file(data, path, filename):
    if not os.path.isdir(path):
        os.makedirs(path)

    with open(f"{path}/{filename}.txt", "a") as f:
        np.savetxt(f, data, fmt="%s", delimiter=" ")

# %%
incidents()

# %% [markdown]
# # Processing no incidents
#
# Need to include the newer base walking stats.

# %%
def no_incidents():
    START = 100
    END = 200
    STEP = 200
    file_list = []
    
    for subdir in os.listdir(root):
        if subdir == "no_incidents":
            for p, s, f in os.walk(os.path.join(root, subdir)):
                for filename in f: 
                    file_list.append(os.path.join(root, subdir, filename))
        else: 
            continue

    data = load_data(file_list)

    acc_results = []
    for sample in data:
        x = convert_signal(sample, type='gyro_total')
        for i in range(START, END, STEP): # 100 because we can overlap samples for no incidents data
            acc_results.append(x[i:i+200])

    gyro_results = []
    for sample in data:
        x = convert_signal(sample, type='acc_total')
        for i in range(START, END, STEP): # 100 because we can overlap samples for no incidents data
            gyro_results.append(x[i:i+200])

    save_file(np.asarray(acc_results), path, 'no_incidents_august_acc')
    save_file(np.asarray(gyro_results), path, 'no_incidents_august_gyro')

# %%
incidents()
# Out:
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S175_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S153_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S151_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S117_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S150_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S119_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S173_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S147_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S116_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S128_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S148_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S111_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S159_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S119_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S178_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S175_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S108_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S171_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S121_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S149_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S131_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S114_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S111_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S178_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S106_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S130_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S118_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S116_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S156_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S114_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S163_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S177_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S171_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S162_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S133_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S137_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S151_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S113_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S180_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S180_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S159_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S158_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S173_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S160_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S131_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S121_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S145_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S107_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S139_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S115_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S112_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S163_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S162_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S148_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S165_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S107_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S112_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S167_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S109_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S120_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S130_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S161_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S127_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S117_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S174_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S144_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S174_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S137_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S133_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S139_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S106_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S160_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S149_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S147_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S154_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S110_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S177_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S167_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S127_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S150_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S109_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S156_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S108_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S153_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S110_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S157_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S166_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S161_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S118_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S166_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S120_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S144_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S115_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S158_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S154_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S145_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S128_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S113_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataRight_S165_20220811.txt
# data/22-08-16/incidents/XqmCw44uUI_rawDataLeft_S157_20220811.txt

# %%
no_incidents()
# Out:
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataLeft_S182_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataLeft_S129_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataRight_S152_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataLeft_S143_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataRight_S125_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataRight_S146_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataRight_S135_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataRight_S126_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataLeft_S104_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataRight_S164_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataRight_S104_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataRight_S169_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataRight_S172_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataLeft_S164_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataLeft_S141_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataLeft_S138_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataRight_S182_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataLeft_S155_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataLeft_S142_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataLeft_S179_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataLeft_S135_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataRight_S134_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataRight_S143_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataLeft_S126_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataRight_S142_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataRight_S123_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataLeft_S172_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataRight_S132_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataLeft_S146_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataLeft_S105_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataLeft_S132_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataRight_S141_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataLeft_S170_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataRight_S105_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataLeft_S169_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataLeft_S125_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataRight_S170_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataRight_S138_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataRight_S179_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataLeft_S134_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataLeft_S152_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataRight_S155_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataRight_S129_20220811.txt
# data/22-08-16/no_incidents/XqmCw44uUI_rawDataLeft_S123_20220811.txt
# /tmp/ipykernel_6971/2083197942.py:29: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   save_file(np.asarray(acc_results), path, 'no_incidents_august_acc')
# /tmp/ipykernel_6971/2083197942.py:30: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   save_file(np.asarray(gyro_results), path, 'no_incidents_august_gyro')
